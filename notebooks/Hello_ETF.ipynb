# %% [markdown]
# <a href="https://colab.research.google.com/github/mickicool/kvantkurs-2025/blob/main/notebooks/Hello_ETF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install yfinance pandas matplotlib

# %%
import yfinance as yf, pandas as pd, matplotlib.pyplot as plt

tickers = ["SPY", "QQQ"]
data = yf.download(tickers, start="2020-01-01")["Close"]
returns = data.pct_change().dropna()
cumulative = (1 + returns).cumprod()

cumulative.plot(title="Total Return 2020–2025")
plt.show()
# Out:
# /tmp/ipython-input-2-1315233688.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start="2020-01-01")["Close"]
# [*********************100%***********************]  2 of 2 completed
# /tmp/ipython-input-2-1315233688.py:5: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = data.pct_change().dropna()
